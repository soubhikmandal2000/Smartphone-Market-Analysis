# %% [markdown]
# Exploratory Data Analysis using Altair, Matplotlib, NumPy, Pandas & Seaborn libraries for Smartphone available in the Indian market with 08 attributes and 2647 samples taken from Flipkart and answered the following questions :
#
# 1. Types of Smartphone available in the market?
# 2. Number of Smartphone manufacturers in the market?
# 3. Types of Smartphone available in the market?
# 4. What are the top 10 Smartphone brands?
# 5. Which brand has the most Smartphone sets on the market?
# 6. Rating (Out of 5) of the Smartphone Brands available in the market?
# 7. Average selling price by Brand, Memory & Storage of the Smartphone?

# %% [markdown]
# **Importing Libraries and Datasets of Smartphone**

# %%
import altair as alt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('C:/Users/SOUBHIK MANDAL/Desktop/jupyter notebook/Smartphone Market Analysis/Flipkart_mobile_brands_scraped_data.csv')
df
# Out:
#        Brand      Model            Color Memory Storage  Rating  \
# 0       OPPO        A53  Moonlight Black   4 GB   64 GB     4.5
# 1       OPPO        A53       Mint Cream   4 GB   64 GB     4.5
# 2       OPPO        A53  Moonlight Black   6 GB  128 GB     4.3
# 3       OPPO        A53       Mint Cream   6 GB  128 GB     4.3
# 4       OPPO        A53   Electric Black   4 GB   64 GB     4.5
# ...      ...        ...              ...    ...     ...     ...
# 2642  Xiaomi  Redmi Y3          Bold Red   4 GB   64 GB     4.3
# 2643  Xiaomi  Redmi Y3      Elegant Blue   3 GB   32 GB     4.3
# 2644  Xiaomi  Redmi Y3      Elegant Blue   4 GB   64 GB     4.2
# 2645  Xiaomi  Redmi Y3       Prime Black   3 GB   32 GB     4.2
# 2646  Xiaomi  Redmi Y3       Prime Black   4 GB   64 GB     4.3
#
#       Selling Price  Original Price
# 0           11990.0         15990.0
# 1           11990.0         15990.0
# 2           13990.0         17990.0
# 3           13990.0         17990.0
# ...

# %%
df.dtypes
# Out:
# Brand              object
# Model              object
# Color              object
# Memory             object
# Storage            object
# Rating            float64
# Selling Price     float64
# Original Price    float64
# dtype: object

# %%
df.nunique()
# Out:
# Brand              16
# Model             773
# Color             531
# Memory             31
# Storage            31
# Rating             24
# Selling Price     784
# Original Price    278
# dtype: int64

# %%
df.describe().T
# Out:
#                  count          mean           std     min      25%      50%  \
# Rating          2647.0      4.001700      0.997499     0.0      4.0      4.3
# Selling Price   2644.0  26461.362330  29833.135164  1000.0   9490.0  14999.0
# Original Price   969.0  29852.605779  27659.141051  1599.0  12999.0  18999.0
#
#                      75%       max
# Rating              4.40       5.0
# Selling Price   29998.25  179900.0
# Original Price  34999.00  189999.0

# %%
colors = ["#0000FF","#00FF00","#FFFF00","#FF7F00","#FF0000","#4361EE"]
palette = sns.color_palette(palette = colors)

sns.palplot(palette, size =1)
plt.show()

# %% [markdown]
# **Brands of smartphone availables in the market with their Original Price vs Selling Price**

# %%
df['Brand'].groupby(df['Brand']).count().sort_values(ascending=False).iloc[:10]
# Out:
# Brand
# SAMSUNG     695
# Apple       364
# realme      285
# OPPO        244
# Nokia       212
# Xiaomi      164
# GIONEE      129
# Lenovo      121
# ASUS        113
# Motorola    105
# Name: Brand, dtype: int64

# %%
alt.Chart(df).mark_point(filled=True,size=40).encode(
    x='Original Price',
    y='Selling Price',
    color='Brand',
    tooltip=['Brand', 'Selling Price', 'Original Price']
).interactive()
# Out:
# alt.Chart(...)

# %%
df.groupby('Brand')['Selling Price'].mean().sort_values(ascending=False).apply(np.ceil)
# Out:
# Brand
# Apple           78066.0
# Google Pixel    61392.0
# IQOO            37190.0
# SAMSUNG         23830.0
# HTC             23798.0
# vivo            23272.0
# LG              19324.0
# ASUS            18729.0
# OPPO            18678.0
# Motorola        16358.0
# Xiaomi          15541.0
# realme          15536.0
# POCO            12649.0
# Lenovo          10084.0
# Nokia            9252.0
# GIONEE           7136.0
# Name: Selling Price, dtype: float64

# %%
sns.barplot(x=df['Brand'], y=df['Selling Price'],palette=colors)
plt.xticks(rotation="vertical")
plt.show()

# %%
df.groupby('Brand')['Original Price'].mean().sort_values(ascending=False).apply(np.ceil)
# Out:
# Brand
# ASUS            66599.0
# Apple           65217.0
# IQOO            40990.0
# SAMSUNG         37669.0
# vivo            31723.0
# Google Pixel    29990.0
# LG              29983.0
# Motorola        27617.0
# OPPO            22922.0
# Xiaomi          19522.0
# realme          16081.0
# POCO            14899.0
# Nokia           11573.0
# Lenovo          10436.0
# GIONEE          10055.0
# HTC                 NaN
# Name: Original Price, dtype: float64

# %%
sns.barplot(x=df['Brand'], y=df['Original Price'],palette=colors)
plt.xticks(rotation="vertical")
plt.show()

# %% [markdown]
# **Rating of the smartphone Brands availables in the market**

# %%
round(df.groupby('Brand')['Rating'].mean().sort_values(ascending=False),1)
# Out:
# Brand
# Google Pixel    4.5
# IQOO            4.4
# POCO            4.3
# vivo            4.2
# OPPO            4.2
# Xiaomi          4.2
# SAMSUNG         4.1
# Motorola        4.1
# HTC             4.1
# ASUS            4.0
# Lenovo          3.9
# LG              3.9
# Apple           3.9
# realme          3.9
# GIONEE          3.8
# Nokia           3.5
# Name: Rating, dtype: float64

# %% [markdown]
# **Memory & Storages of the Television Brands availables in the market**

# %%
df['Brand'].groupby(df['Memory']).count().sort_values(ascending=False)
# Out:
# Memory
# 4 GB      631
# 3 GB      445
# 6 GB      381
# 2 GB      345
# 8 GB      264
# 1 GB      175
# 4GB       114
# 12 GB      45
# 4 MB       39
# 512 MB     33
# 1.5 GB     27
# 64 MB      16
# 16 MB      16
# 32 MB      14
# 8 MB       14
# 6GB        11
# 128 MB      6
# 768 MB      6
# 100 MB      3
# 10 MB       3
# 0.5 GB      2
# 256 MB      2
# 2 MB        2
# 46 MB       2
# 16 GB       2
# 717 MB      2
# 30 MB       1
# 32 GB       1
# 18 GB       1
# 153 MB      1
# 0 MB        1
# Name: Brand, dtype: int64

# %%
sns.barplot(x=df['Memory'], y=df['Selling Price'],palette=colors)
plt.xticks(rotation="vertical")
plt.show()

# %%
alt.Chart(df).mark_point(filled=True,size=40).encode(
    x='Original Price',
    y='Selling Price',
    color='Memory',
    tooltip=['Memory', 'Selling Price', 'Original Price']
).interactive()
# Out:
# alt.Chart(...)

# %%
sns.set_style('white')
plt.figure(figsize=(10,7))
sns.countplot(y="Brand", hue="Memory", data=df, palette=colors,order=df["Brand"].value_counts().iloc[:5].index)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Brand'>

# %%
df['Brand'].groupby(df['Storage']).count().sort_values(ascending=False)
# Out:
# Storage
# 64 GB                    641
# 128 GB                   612
# 32 GB                    472
# 16 GB                    287
# 256 GB                   197
# 8 GB                     125
# 512 GB                    58
# 4 GB                      50
# 4 MB                      28
# 16 MB                     14
# Expandable Upto 32 GB     14
# 128 MB                    12
# Expandable Upto 16 GB     12
# 1 TB                       9
# 8 MB                       6
# 2.27 MB                    4
# 64 MB                      3
# 48 MB                      3
# 256 MB                     3
# 2 MB                       3
# 1 MB                       2
# 512 MB                     2
# 100 MB                     2
# 0 MB                       2
# 32GB                       1
# 2.3 MB                     1
# 153 MB                     1
# 64GB GB                    1
# 65 GB                      1
# 140 MB                     1
# 10 MB                      1
# Name: Brand, dtype: int64

# %%
sns.barplot(x=df['Storage'], y=df['Selling Price'],palette=colors)
plt.xticks(rotation="vertical")
plt.show()

# %%
alt.Chart(df).mark_point(filled=True,size=40).encode(
    x='Original Price',
    y='Selling Price',
    color='Storage',
    tooltip=['Storage', 'Selling Price', 'Original Price']
).interactive()
# Out:
# alt.Chart(...)

# %%
sns.set_style('white')
plt.figure(figsize=(10,7))
sns.countplot(y="Brand", hue="Storage", data=df, palette=colors,order=df["Brand"].value_counts().iloc[:5].index)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Brand'>
